# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

print(sqlite_index.count())
# Out:
# 85

# %%
from dotenv import load_dotenv
load_dotenv()

from rag_helper import RAGBase
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

assistant = RAGBase(
    index=sqlite_index,
    llm_client=openai_client,
)

answer = assistant.rag("Can I still join the course after it started?")
print(answer)
# Out:
# Yes, you can still join the course after it started, but to receive a certificate, you need to submit your project while the form is still accepting submissions, as stated in the first part of the provided context for "General Course-Related Questions: I just discovered the course. Can I still join?".
